# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
geopark = gpd.read_file('../data/parks.geojson')
print(geopark.crs)
geopark.head( )
# Out:
# epsg:4326
#   school community       city zipcode          acres             name  \
# 0   None        No    Antioch   37013            622  Mill Ridge Park
# 1   None        No    Antioch   37013          23.94             None
# 2     No        No    Madison   37115          10.25             None
# 3   None        No  Nashville   37204  1.41582132469             None
# 4   None        No  Nashville   37221           0.48             None
#
#   football_m classifica     shape_area camping  ... community_1 images  \
# 0       None       None   27005433.936    None  ...        None   None
# 1       None       None  1038220.47526    None  ...        None   None
# 2         No     <Null>   436585.60938      No  ...          No   None
# 3         No       None  61672.9302239    None  ...        None   None
# 4       None       None  22116.8493151    None  ...        None   None
#
#   historic restroom            lat volleyball phone         descriptio  \
# 0      Yes       No              0       None  None               None
# 1     None       No              0       None  None               None
# 2       No       No  1773033.44088         No  None  Under development
# 3     None       No              0         No  None               None
# 4     None       No              0       None  None               None
#
#   dog_park                                           geometry
# 0     None  MULTIPOLYGON (((-86.61072 36.01596, -86.61072 ...
# 1     None  MULTIPOLYGON (((-86.64436 36.04331, -86.64399 ...
# 2       No  MULTIPOLYGON (((-86.66357 36.24040, -86.66203 ...
# 3     None  MULTIPOLYGON (((-86.77956 36.11125, -86.77960 ...
# 4     None  MULTIPOLYGON (((-86.94581 36.05387, -86.94600 ...
#
# [5 rows x 62 columns]

# %%
type(parks)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
acq = pd.read_csv('../data/Land_Bank_Acquisitions.csv')
print(acq.shape)
acq.head(3)
# Out:
# (85, 62)
#                                             the_geom  OBJECTID  \
# 0  MULTIPOLYGON (((-86.61071546296412 36.01595663...       767
# 1  MULTIPOLYGON (((-86.64435926660656 36.04331318...       768
# 2  MULTIPOLYGON (((-86.66356718599474 36.24039647...       769
#
#               NAME   PARK_ID           LAT            LON  YEAR_ESTAB   ACRES  \
# 0  Mill Ridge Park       NaN  0.000000e+00       0.000000           0  622.00
# 1              NaN       NaN  0.000000e+00       0.000000           0   23.94
# 2              NaN  PARK_102  1.773033e+06  693951.625375           0   10.25
#
#   DAYS_OPEN          HOURS  ... Canoe_Laun Community1 Par_Finder  \
# 0       NaN            NaN  ...        NaN        NaN        NaN
# 1       NaN            NaN  ...        NaN        NaN        NaN
# 2       NaN  Dawn to 11 pm  ...         No         No        NaN
#
#                      COMMON_NAM PARK_NUM CLASSIFICA     CITY STATE  ZIPCODE  \
# 0  Southeast Park Property Park       31        NaN  Antioch    TN  37013.0
# 1  Southeast Park Property Park       31        NaN  Antioch    TN  37013.0
# 2                    Brake Park        9     <Null>  Madison    TN  37115.0
#
#   Council_D
# 0       NaN
# 1       NaN
# 2       NaN
#
# [3 rows x 62 columns]

# %%
acq['geometry'] = acq.apply(lambda x: Point((float(x.LON), 
                                                         float(x.LAT))), 
                                        axis=1)
acq.head(3)
# Out:
#                                             the_geom  OBJECTID  \
# 0  MULTIPOLYGON (((-86.61071546296412 36.01595663...       767
# 1  MULTIPOLYGON (((-86.64435926660656 36.04331318...       768
# 2  MULTIPOLYGON (((-86.66356718599474 36.24039647...       769
#
#               NAME   PARK_ID           LAT            LON  YEAR_ESTAB   ACRES  \
# 0  Mill Ridge Park       NaN  0.000000e+00       0.000000           0  622.00
# 1              NaN       NaN  0.000000e+00       0.000000           0   23.94
# 2              NaN  PARK_102  1.773033e+06  693951.625375           0   10.25
#
#   DAYS_OPEN          HOURS  ... Community1 Par_Finder  \
# 0       NaN            NaN  ...        NaN        NaN
# 1       NaN            NaN  ...        NaN        NaN
# 2       NaN  Dawn to 11 pm  ...         No        NaN
#
#                      COMMON_NAM PARK_NUM CLASSIFICA     CITY STATE  ZIPCODE  \
# 0  Southeast Park Property Park       31        NaN  Antioch    TN  37013.0
# 1  Southeast Park Property Park       31        NaN  Antioch    TN  37013.0
# 2                    Brake Park        9     <Null>  Madison    TN  37115.0
#
#   Council_D                                 geometry
# 0       NaN                              POINT (0 0)
# 1       NaN                              POINT (0 0)
# 2       NaN  POINT (693951.6253749999 1773033.44088)
#
# [3 rows x 63 columns]
